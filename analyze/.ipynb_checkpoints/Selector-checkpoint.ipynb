# %%
from Selector import *
import sys
import time
from datetime import datetime
from view.HTML import show
import json
from indicators.MA import *
from indicators.Gap import *
# from indicators.Trend import *
from strategy.sequence.MAStrategy import *
from strategy.sequence.RStrategy import *
from simulation.Simulator import *
sys.path.append("../data")
import StockDao as sd
from view.ViewDataFactory import *
from strategy.sequence.StrategyS1 import *
from simulation.Simulator import *

# %%
def  up(list,i):
    k = list[i]
    pk = list[i-1]
    if (k.low - pk.high)/pk.high > 0.01 and k.high == k.close and k.high > k.low:
        return True
    return False

# %%
def wave(list,i):
    """
    """
    if len(list) < 40:
        return False
    current = i - 15
    lk = list[i]
    flag = False
    bk = None
    while current <= i:
        k = list[current]
        if not k.isUp():
            current = current + 1
            continue
        k5 = list[current-5]
        k10 = list[current-10]
        k15 = list[current-15]
        r5 = (k.close - k5.close)/k5.close
        r10 = (k.close - k10.close)/k10.close
        r15 = (k.close - k15.close)/k15.close
        if r5 < -0.35:
            return False
        if r10 < -0.35:
            return False
        if r15 < -0.35:
            return False
        if lk.low > k5.high and r5 > 0.4:
            flag = True
            bk = k5
        if lk.low > k10.high and r10 > 0.4:
            flag = True
            bk = k10
        if lk.low > k15.high and r15 > 0.4:
            flag = True
            bk = k15
        if (k.close - lk.close)/lk.close > 0.4:
            return False
        current = current + 1
        
    #如果当前跌得太多
    if flag and (k.close - bk.close)/bk.close < 0.2:
            return False
    
    return flag

# %%
def down(list,i):
    k = list[-1]
    if not k.isDown():
        return False
    j = i-1
    h = i - 4
    while j>=h:
        kc = list[j]
        if kc.isDown() or kc.open < k.close:
            return False
        j = j - 1
    return True

# %%
def decide(list,i,trend,ma10,ma20,ma60,gap):
        """
        策略
        :param list: 测试数据
        :param trader: 交易者
        :param i: 当前在list中的位置
        :return:
        """
        k = list[i]
        pre = list[i-1]
        if gap.support(k.date,k.close,pre.minOC(),20) and k.isDown():
            return True,1
#         if up(list,i):
#             return True,2
#         if wave(list,i):
#             return True,3
        if down(list,i):
            return True,4
        return False,-1

# %%
def firgueF(self,code):
    """显示股票"""
    #获取数据
    begin = "20160105"
    end = None
#     begin = "20150105"
#     end = '20160722'
    listK = sd.get_k_data(code,begin ,end)
    data,volume = ViewDataFactory.getCandlestick(listK)
    madic = ViewDataFactory.getMA(listK,(20,60))
    trendLine,trendMergeLine,trendBig = ViewDataFactory.getTrendLine(listK)
    
    #获取开始显示的时间
    mDate = 0
#     if len(data)>0:
#         if len(listK)/2>abs(-250):
#             mDate = data[-250][0]
#         else:
#             mDate = data[len(listK)/2][0]
    if len(data)>100:
        mDate = data[-100][0]
    else:
        mDate = data[len(data)][0]
            
    #显示
    params = {}
    params["code"] = code
    params["condition"] = self.condition.get(code,-100)
    params["mDate"] = mDate
    params["data"] = json.dumps(data)
    params["volume"] = json.dumps(volume)
    params["line20"] = json.dumps(madic[20].line)
    params["line60"] = json.dumps(madic[60].line)
    params["trendLine"] = json.dumps(trendLine)
    params["trendMergeLine"] = json.dumps(trendMergeLine)
    params["trendBig"] = json.dumps(trendBig)
    clear_output()
    show("Selector.html",params)

# %%
class KB(Selector):
    """红绿红"""
    condition = {}
    def analyze(self,list):
        """分析股票"""
#         if len(list) < 50:
#             return False
        i = 0
        flag = False
        trend = Trend()
        ma10 = MA(10)
        ma20 = MA(20)
        ma60 = MA(60)
        gap = Gap(0.05)
        while i < len(list):
            k = list[i]
#             trend.add(k)
#             ma10.add(k.date,k.close)
#             ma20.add(k.date,k.close)
#             ma60.add(k.date,k.close)
            gap.fresh(k)
            i += 1
        flag,condition = decide(list,len(list)-1,trend,ma10,ma20,ma60,gap)
        if flag == True:
            self.condition[list[0].code] = condition
        return flag
    
    def firgue(self,code):
        """显示股票"""
        firgueF(self,code)

# %%
kb = KB(True,'20180101')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
# <title>stock</title>
# <script src="/files/analyze/view/js/jquery-3.1.1.min.js"></script>
# <script src="/files/analyze/view/js/highstock6.js"></script>
# <!--<script src="/files/analyze/view/js/indicators.js"></script>-->
# <!--<script src="/files/analyze/view/js/sma.js"></script>-->
# <!--<script src="/files/analyze/view/js/annotations.js"></script>-->
# <script type="text/javascript">
#
#     // create the chart
#     var chart = Highcharts.stockChart('container', {
#             legend: {
#                 enabled: true
#             },
#             plotOptions: {
#                  candlestick: {
# //                            color: '#00eba5',
# //                            lineColor: '#2AEBAF',
# //                            color: '#41BEF1',
# //                            lineColor: '#41BEF1',
# //                            color: '#53B987',
# //                            lineColor: '#7CB5EC',
#                             color: '#53B987',
#                             lineColor: '#53B987',
# //                            color: '#AAAAAA',
# //                            lineColor: '#AAAAAA',
#                             upColor:'red',
#                             upLineColor: 'red'
#                         },
#                  column: {
# //                           color: '#53B987'
#                              color: '#434348'
# //                           color: '#7CB5EC'
#                         }
#             },
#             chart: {
#                 height: '680px',
#             },
#             rangeSelector: {
#                enabled:false
#             },
#             tooltip: {
#                 crosshairs: [true,true],
#                 formatter: function () {
#                     if(this.point) {
#                         console.log(this.point)
#                         return "condition:"+this.point.text
#                     }
#                     var preIndex = this.points[0].series.points.indexOf( this.points[0].point)-1;
#                     preIndex = preIndex<0?0:preIndex;
#                     var preClose = this.points[0].series.points[preIndex].close;
#                     var close = this.points[0].point.close;
#                     var open = this.points[0].point.open;
#                     var raise = preClose==0?'-':(((close-preClose)/preClose*100).toFixed(2)+'%');
#                     var ratio = (open==0?'-': ((close-open)/open*100).toFixed(2))+'%';
#                     var earn = typeof this.points[2] =='undefined'?'-':this.points[2].point.y.toFixed(4);
#                     var maEarn = typeof this.points[3] =='undefined'?'-':this.points[3].point.y.toFixed(4);
#                     var rEarn = typeof this.points[4] =='undefined'?'-':this.points[4].point.y.toFixed(4);
#                     return '<b>' + Highcharts.dateFormat('%Y-%m-%d',this.x+1000*24*60*60) +'</b>'
#                     +'<br>'+'<b>'+'code: '+'</b>' + this.points[0].series.name
#                     +'<br>'+'<b>'+'open: '+'</b>' + open
#                     +'<br>'+'<b>'+'close: '+'</b>' + close
# //                    +'<br>'+'<b>'+'preClose: '+'</b>' + preClose
#                     +'<br>'+'<b>'+'hight: '+'</b>' + this.points[0].point.high
#                     +'<br>'+'<b>'+'low: '+'</b>' + this.points[0].point.low
#                     +'<br>'+'<b>'+'volume: '+'</b>' + this.points[1].point.y
#                     +'<br>'+'<b>'+'ratio: '+'</b>' + ratio
#                     +'<br>'+'<b>'+'raise: '+'</b>' + raise
#                     +'<br>'+'<b>'+'earn: '+'</b>' + earn
#                     +'<br>'+'<b>'+'maEarn: '+'</b>' + maEarn
#                     +'<br>'+'<b>'+'rEarn: '+'</b>' + rEarn
#
#                 },
#                positioner: function (labelWidth, labelHeight, point) {
#                     var tooltipX, tooltipY;
#                     if (point.plotX + labelWidth + labelWidth > chart.plotWidth) {
#                         tooltipX = point.plotX + chart.plotLeft - labelWidth - labelWidth;
#                     } else {
#                         tooltipX = point.plotX + chart.plotLeft + labelWidth;
#                     }
#                     tooltipY = point.plotY + labelHeight;
#                     return {
#                         x: tooltipX,
#                         y: tooltipY
#                     };
#                 },
# //                followPointer: true,
#                 split:false,
#                 shared: true
#             },
#             title: {
#                 text: '603196.SH'+' 4'
#              },
#             xAxis: {
#                 type: 'datetime',
#                 min: 1528300800000
#               },
#             yAxis: [{
#                 top: '0%',
#                 height: '65%',
#                 lineWidth: 2,
#                 crosshair:{
#                     zIndex: 1000000
#                 }
#             },{
#                 gridLineWidth: 0,
#                 top: '50%',
#                 height: '15%',
#                 offset: 0,
#                 lineWidth: 2
#
#             },{
#                 top: '65%',
#                 height: '30%',
#                 offset: 0,
#                 lineWidth: 2
#             }],
#             series: [
#                 {
#                     id: 'k',
#                     zIndex: 2,
#                     type: 'candlestick',
#                     name: '603196.SH',
#                     data: [[1496160000000, 8.5, 10.2, 8.5, 10.2], [1496246400000, 11.22, 11.22, 11.22, 11.22], [1496332800000, 12.34, 12.34, 12.34, 12.34], [1496592000000, 13.57, 13.57, 13.57, 13.57], [1496678400000, 14.93, 14.93, 14.93, 14.93], [1496764800000, 16.42, 16.42, 16.42, 16.42], [1496851200000, 18.06, 18.06, 18.06, 18.06], [1496937600000, 19.87, 19.87, 19.87, 19.87], [1497196800000, 20.48, 21.86, 20.11, 21.86], [1497283200000, 21.49, 